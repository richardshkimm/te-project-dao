# %%
from main import *

# %%
import matplotlib.pyplot as plt

times = []
num_nodes = list(range(5, 201, 10))
for size in num_nodes:
    graph = generate_graph(size)
    demands = generate_demands(size)
    model, flow = create_mcf_model(graph, demands, mlu_weight=0, extra_credit=True)
    times.append(model.Runtime)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-04-21
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 50 rows, 35 columns and 233 nonzeros
# Model fingerprint: 0x143b7fea
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 50 rows and 35 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.8460159e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds (0.00 work units)
# Optimal objective  5.846015852e+05
#
# Results:
# MLU: 0.05331242991027309
# Demand met: 584601.5851556375 out of 697337.5477641359
# Percent of demand met: 0.838333726657969
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 516 rows, 2101 columns and 19906 nonzeros
# Model fingerprint: 0x36268d25
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 516 rows and 2101 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.2436018e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  5.243601816e+06
#
# Results:
# MLU: 0.33482785040659285
# Demand met: 5243601.816425105 out of 5668836.257011624
# Percent of demand met: 0.9249873481421237
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 1470 rows, 6001 columns and 52815 nonzeros
# Model fingerprint: 0xc56ec3f6
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 938 rows and 3969 columns
# Presolve time: 0.01s
# Presolved: 532 rows, 2032 columns, 4318 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.02 seconds (0.02 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       20    1.5204829e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 20 iterations and 0.02 seconds (0.02 work units)
# Optimal objective  1.520482924e+07
#
# Results:
# MLU: 0.27047694647470505
# Demand met: 15204829.241547441 out of 15798480.96296153
# Percent of demand met: 0.9624234935747389
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2996 rows, 11901 columns and 89170 nonzeros
# Model fingerprint: 0x6c4f16fd
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 2617 rows and 11041 columns
# Presolve time: 0.02s
# Presolved: 379 rows, 860 columns, 1085 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 2.250e+02
#  Factor NZ  : 1.039e+03 (roughly 1 MB of memory)
#  Factor Ops : 1.135e+04 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.02 seconds (0.02 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        5    2.9996725e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.03 seconds (0.03 work units)
# Optimal objective  2.999672490e+07
#
# Results:
# MLU: 0.3262110581734899
# Demand met: 29996724.902801976 out of 30877677.921207987
# Percent of demand met: 0.9714695832810362
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 4966 rows, 19801 columns and 140053 nonzeros
# Model fingerprint: 0xef974995
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 4966 rows and 19801 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.0161123e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.04 work units)
# Optimal objective  5.016112309e+07
#
# Results:
# MLU: 0.20501639190274473
# Demand met: 50161123.08699214 out of 51335243.220215514
# Percent of demand met: 0.9771283808243258
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 7454 rows, 29701 columns and 204117 nonzeros
# Model fingerprint: 0x10b5b9cc
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 7454 rows and 29701 columns
# Presolve time: 0.03s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5704720e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.05 work units)
# Optimal objective  7.570471964e+07
#
# Results:
# MLU: 0.2038302195918404
# Demand met: 75704719.63709931 out of 77244898.60113648
# Percent of demand met: 0.9800610915163463
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 10444 rows, 41601 columns and 285358 nonzeros
# Model fingerprint: 0xf1711de1
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 10444 rows and 41601 columns
# Presolve time: 0.04s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0718320e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.06 seconds (0.07 work units)
# Optimal objective  1.071831989e+08
#
# Results:
# MLU: 0.21300081271743848
# Demand met: 107183198.88855216 out of 108952992.49073142
# Percent of demand met: 0.9837563561888416
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 13874 rows, 55501 columns and 378893 nonzeros
# Model fingerprint: 0x57c2cab0
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 13874 rows and 55501 columns
# Presolve time: 0.05s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4237428e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.06 seconds (0.10 work units)
# Optimal objective  1.423742808e+08
#
# Results:
# MLU: 0.22066961446282468
# Demand met: 142374280.8397742 out of 144205912.8049092
# Percent of demand met: 0.9872984960913984
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 17906 rows, 71401 columns and 488237 nonzeros
# Model fingerprint: 0xee22f35f
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 17906 rows and 71401 columns
# Presolve time: 0.08s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8104542e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.10 seconds (0.14 work units)
# Optimal objective  1.810454215e+08
#
# Results:
# MLU: 0.38284801635344945
# Demand met: 181045421.53510594 out of 183000890.03645557
# Percent of demand met: 0.9893144317442386
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 22324 rows, 89301 columns and 609456 nonzeros
# Model fingerprint: 0xc0d9df3c
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 18363 rows and 67389 columns
# Presolve time: 0.12s
# Presolved: 3961 rows, 21912 columns, 41966 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 1.968e+04
#  Factor NZ  : 2.757e+04 (roughly 10 MB of memory)
#  Factor Ops : 4.783e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.14 seconds (0.20 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      224    2.2808482e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 224 iterations and 0.17 seconds (0.21 work units)
# Optimal objective  2.280848157e+08
#
# Results:
# MLU: 0.366807424695967
# Demand met: 228084815.68243635 out of 230561541.033615
# Percent of demand met: 0.9892578556680555
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 27276 rows, 109201 columns and 744894 nonzeros
# Model fingerprint: 0x84cb72f8
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 20476 rows and 58493 columns
# Presolve time: 0.16s
# Presolved: 6800 rows, 50708 columns, 105800 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 5.464e+04
#  Factor NZ  : 8.960e+04 (roughly 24 MB of memory)
#  Factor Ops : 5.814e+06 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.21 seconds (0.29 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      966    2.8038210e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 966 iterations and 0.24 seconds (0.29 work units)
# Optimal objective  2.803821018e+08
#
# Results:
# MLU: 0.35657115084971475
# Demand met: 280382101.8333619 out of 283037156.73514575
# Percent of demand met: 0.9906194121916356
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 32814 rows, 131101 columns and 895401 nonzeros
# Model fingerprint: 0xcb749f01
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 24957 rows and 69117 columns
# Presolve time: 0.18s
# Presolved: 7857 rows, 61984 columns, 131134 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.03s
#
# Barrier statistics:
#  AA' NZ     : 6.894e+04
#  Factor NZ  : 1.125e+05 (roughly 30 MB of memory)
#  Factor Ops : 8.016e+06 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.25 seconds (0.35 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1622    3.3335762e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 1622 iterations and 0.28 seconds (0.35 work units)
# Optimal objective  3.333576195e+08
#
# Results:
# MLU: 0.3822683060595661
# Demand met: 333357619.4996111 out of 336263689.95954853
# Percent of demand met: 0.9913577631284334
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 38724 rows, 155001 columns and 1057446 nonzeros
# Model fingerprint: 0xaf83385b
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 29626 rows and 80929 columns
# Presolve time: 0.23s
# Presolved: 9098 rows, 74072 columns, 158456 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.03s
#
# Barrier performed 0 iterations in 0.29 seconds (0.42 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2292    3.9391400e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 2292 iterations and 0.34 seconds (0.42 work units)
# Optimal objective  3.939139953e+08
#
# Results:
# MLU: 0.49784853288272307
# Demand met: 393913995.3294634 out of 397010696.99358475
# Percent of demand met: 0.992199954087959
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 45088 rows, 180901 columns and 1232382 nonzeros
# Model fingerprint: 0x81806192
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 34244 rows and 93443 columns
# Presolve time: 0.26s
# Presolved: 10844 rows, 87458 columns, 187042 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.04s
#
# Barrier statistics:
#  AA' NZ     : 9.959e+04
#  Factor NZ  : 1.762e+05 (roughly 40 MB of memory)
#  Factor Ops : 1.882e+07 (less than 1 second per iteration)
#  Threads    : 6
#
# Barrier performed 0 iterations in 0.37 seconds (0.50 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2976    4.6144249e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 2976 iterations and 0.42 seconds (0.49 work units)
# Optimal objective  4.614424943e+08
#
# Results:
# MLU: 0.42237335979141244
# Demand met: 461442494.2557669 out of 464856455.8849245
# Percent of demand met: 0.9926558799260762
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 51926 rows, 208801 columns and 1420539 nonzeros
# Model fingerprint: 0x47af2750
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 39173 rows and 102801 columns
# Presolve time: 0.29s
# Presolved: 12753 rows, 106000 columns, 228140 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier performed 0 iterations in 0.38 seconds (0.59 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3928    5.3479513e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 3928 iterations and 0.45 seconds (0.58 work units)
# Optimal objective  5.347951328e+08
#
# Results:
# MLU: 0.40783346877210297
# Demand met: 534795132.8032159 out of 537914023.5736765
# Percent of demand met: 0.994201878676187
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 59526 rows, 238701 columns and 1626669 nonzeros
# Model fingerprint: 0xd17873c3
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 44818 rows and 115925 columns
# Presolve time: 0.37s
# Presolved: 14708 rows, 122776 columns, 263746 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier performed 0 iterations in 0.48 seconds (0.68 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4636    6.0907625e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 4636 iterations and 0.55 seconds (0.69 work units)
# Optimal objective  6.090762546e+08
#
# Results:
# MLU: 0.40113687713961116
# Demand met: 609076254.5785995 out of 613232978.9251267
# Percent of demand met: 0.9932216229567218
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 67654 rows, 270601 columns and 1846911 nonzeros
# Model fingerprint: 0x5c7eebff
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 47499 rows and 114887 columns
# Presolve time: 0.38s
# Presolved: 20155 rows, 155714 columns, 337430 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier performed 0 iterations in 0.53 seconds (0.79 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     6048    6.9240844e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 6048 iterations and 0.61 seconds (0.81 work units)
# Optimal objective  6.924084429e+08
#
# Results:
# MLU: 0.44936962165735006
# Demand met: 692408442.8765666 out of 696811026.4448634
# Percent of demand met: 0.9936818112785057
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 76346 rows, 304501 columns and 2081859 nonzeros
# Model fingerprint: 0x8b258296
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 45423 rows and 81643 columns
# Presolve time: 0.52s
# Presolved: 30923 rows, 222858 columns, 522828 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.30s
#
# Barrier performed 0 iterations in 0.93 seconds (1.11 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7606    7.7396688e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 7606 iterations and 1.03 seconds (1.05 work units)
# Optimal objective  7.739668814e+08
#
# Results:
# MLU: 0.5459968882655549
# Demand met: 773966881.402732 out of 778560738.6719738
# Percent of demand met: 0.9940995518511789
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 84996 rows, 340401 columns and 2321514 nonzeros
# Model fingerprint: 0x9b9f8b59
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 49155 rows and 55093 columns
# Presolve time: 0.55s
# Presolved: 35841 rows, 285308 columns, 726402 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.19s
#
# Barrier performed 0 iterations in 0.88 seconds (1.23 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    10032    8.6918065e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 10032 iterations and 0.99 seconds (1.19 work units)
# Optimal objective  8.691806453e+08
#
# Results:
# MLU: 0.49206422950825196
# Demand met: 869180645.2812678 out of 873896329.6310657
# Percent of demand met: 0.9946038400781603
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[arm])
#
# CPU model: Apple M2
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 94568 rows, 378301 columns and 2581782 nonzeros
# Model fingerprint: 0xe3b3b00a
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 54631 rows and 52107 columns
# Presolve time: 0.61s
# Presolved: 39937 rows, 326194 columns, 841288 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.18s
#
# Barrier performed 0 iterations in 0.97 seconds (1.36 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11694    9.6279816e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 11694 iterations and 1.08 seconds (1.34 work units)
# Optimal objective  9.627981594e+08
#
# Results:
# MLU: 0.44656358882428604
# Demand met: 962798159.3610029 out of 967666168.4747249
# Percent of demand met: 0.9949693300517107

# %%
plt.plot(num_nodes,times)
plt.suptitle('Solving Time vs. Graph Size', fontweight='bold')
plt.title('Max Throughput',fontsize='small')
plt.xticks(num_nodes)
plt.tick_params('x', labelsize=6)
plt.xlabel('# Nodes')
plt.ylabel('Time (s)')
plt.savefig('extra-credit.png')
plt.show()
