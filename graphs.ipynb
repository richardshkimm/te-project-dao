# %%
from main import *

# %%
graph = parse_topology('topology.txt')
draw(graph)

# %%
import matplotlib.pyplot as plt

times = []
for size in range(5, 201, 10):
    graph = generate_graph(size)
    demands = generate_demands(size)
    model, flow = create_mcf_model(graph, demands)
    times.append(model.Runtime)
# Out:
# <enumerate object at 0x0000027C2C5F4180>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 170 rows, 159 columns and 517 nonzeros
# Model fingerprint: 0xbab2d6df
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [6e+03, 5e+06]
# Presolve removed 170 rows and 159 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.2964163e+05   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.02 seconds (0.00 work units)
# Optimal objective  5.296416312e+05
# Demand met: 0 out of 615418.3118102511
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE0662740>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 9502 rows, 11089 columns and 38089 nonzeros
# Model fingerprint: 0x20af8a2a
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 9325 rows and 10643 columns
# Presolve time: 0.03s
# Presolved: 177 rows, 446 columns, 446 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.2990392e+06   2.982447e+05   0.000000e+00      0s
#      235    5.2990392e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 235 iterations and 0.05 seconds (0.02 work units)
# Optimal objective  5.299039166e+06
# Demand met: 0 out of 5725405.081528585
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE0045A80>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 18858 rows, 23347 columns and 84890 nonzeros
# Model fingerprint: 0x95badd15
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 18445 rows and 22087 columns
# Presolve time: 0.06s
# Presolved: 413 rows, 1260 columns, 2278 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 7.810e+02
#  Factor NZ  : 1.632e+03 (roughly 1 MB of memory)
#  Factor Ops : 1.489e+04 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.08 seconds (0.04 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       10    1.4248082e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.11 seconds (0.04 work units)
# Optimal objective  1.424808237e+07
# Demand met: 0 out of 14850760.450465528
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BD5DE9E40>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 31138 rows, 40055 columns and 145896 nonzeros
# Model fingerprint: 0x80883798
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 30979 rows and 39736 columns
# Presolve time: 0.08s
# Presolved: 159 rows, 319 columns, 318 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9894549e+07   5.039536e+02   0.000000e+00      0s
#      159    2.9894549e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 159 iterations and 0.11 seconds (0.07 work units)
# Optimal objective  2.989454902e+07
# Demand met: 0 out of 30894747.264066365
# Percent of demand met: 0.0
# <enumerate object at 0x0000027D03AACF00>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 47740 rows, 62625 columns and 227858 nonzeros
# Model fingerprint: 0x8e10aed2
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 47414 rows and 61965 columns
# Presolve time: 0.12s
# Presolved: 326 rows, 660 columns, 658 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier performed 0 iterations in 0.13 seconds (0.10 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      332    5.1254270e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 332 iterations and 0.18 seconds (0.12 work units)
# Optimal objective  5.125426966e+07
# Demand met: 0 out of 52452772.46022119
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BED228240>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 66284 rows, 88589 columns and 323484 nonzeros
# Model fingerprint: 0xfc3e8b0c
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 66284 rows and 88589 columns
# Presolve time: 0.15s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.5052181e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.19 seconds (0.17 work units)
# Optimal objective  7.505218147e+07
# Demand met: 0 out of 76578096.22907737
# Percent of demand met: 0.0
# <enumerate object at 0x0000027B91BCA000>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 90154 rows, 121391 columns and 443904 nonzeros
# Model fingerprint: 0xcffa34c5
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 90154 rows and 121391 columns
# Presolve time: 0.25s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.0658807e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.33 seconds (0.24 work units)
# Optimal objective  1.065880721e+08
# Demand met: 0 out of 108158198.90025851
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C2A5AB940>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 119346 rows, 160969 columns and 589807 nonzeros
# Model fingerprint: 0x2bc730b9
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 119346 rows and 160969 columns
# Presolve time: 0.27s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4051248e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.34 seconds (0.33 work units)
# Optimal objective  1.405124819e+08
# Demand met: 0 out of 142349989.39467236
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BF40B0580>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 153554 rows, 207137 columns and 758265 nonzeros
# Model fingerprint: 0xc8feff75
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 152736 rows and 205232 columns
# Presolve time: 0.33s
# Presolved: 818 rows, 1905 columns, 2291 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 3.780e+02
#  Factor NZ  : 2.066e+03 (roughly 1 MB of memory)
#  Factor Ops : 2.254e+04 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.35 seconds (0.37 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       11    1.8071835e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.45 seconds (0.45 work units)
# Optimal objective  1.807183492e+08
# Demand met: 0 out of 182908334.67712596
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE0785300>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 192012 rows, 259005 columns and 948600 nonzeros
# Model fingerprint: 0xdeef023a
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 187245 rows and 234073 columns
# Presolve time: 0.42s
# Presolved: 4767 rows, 24932 columns, 47186 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.01s
#
# Barrier statistics:
#  AA' NZ     : 2.176e+04
#  Factor NZ  : 3.148e+04 (roughly 12 MB of memory)
#  Factor Ops : 6.195e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.46 seconds (0.48 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      262    2.2661678e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 262 iterations and 0.59 seconds (0.58 work units)
# Optimal objective  2.266167842e+08
# Demand met: 0 out of 229369924.37056243
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BDF614840>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 234822 rows, 316765 columns and 1159725 nonzeros
# Model fingerprint: 0x79069af8
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 227699 rows and 269959 columns
# Presolve time: 0.55s
# Presolved: 7123 rows, 46806 columns, 94102 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.02s
#
# Barrier statistics:
#  AA' NZ     : 4.673e+04
#  Factor NZ  : 7.309e+04 (roughly 22 MB of memory)
#  Factor Ops : 3.398e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.62 seconds (0.62 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#      884    2.7607695e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 884 iterations and 0.77 seconds (0.73 work units)
# Optimal objective  2.760769485e+08
# Demand met: 0 out of 278950230.94016
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C73AB1A80>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 281850 rows, 380161 columns and 1393125 nonzeros
# Model fingerprint: 0x3062cdb3
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 273484 rows and 317681 columns
# Presolve time: 0.72s
# Presolved: 8366 rows, 62480 columns, 130722 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.04s
#
# Barrier statistics:
#  AA' NZ     : 6.783e+04
#  Factor NZ  : 1.138e+05 (roughly 30 MB of memory)
#  Factor Ops : 8.645e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.82 seconds (0.77 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1530    3.3373851e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 1530 iterations and 1.01 seconds (0.89 work units)
# Optimal objective  3.337385059e+08
# Demand met: 0 out of 336437084.9489019
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE046A300>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 333216 rows, 449433 columns and 1647300 nonzeros
# Model fingerprint: 0x7a8218f1
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 323085 rows and 370211 columns
# Presolve time: 0.68s
# Presolved: 10131 rows, 79222 columns, 168748 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.05s
#
# Barrier statistics:
#  AA' NZ     : 8.927e+04
#  Factor NZ  : 1.571e+05 (roughly 40 MB of memory)
#  Factor Ops : 1.570e+07 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.79 seconds (0.89 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2490    3.9824433e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 2490 iterations and 0.99 seconds (1.02 work units)
# Optimal objective  3.982443328e+08
# Demand met: 0 out of 401576175.3230023
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C2A592CC0>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 388710 rows, 524161 columns and 1924875 nonzeros
# Model fingerprint: 0x8c4542ad
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 376331 rows and 429329 columns
# Presolve time: 0.78s
# Presolved: 12379 rows, 94832 columns, 201964 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.04s
#
# Barrier statistics:
#  AA' NZ     : 1.071e+05
#  Factor NZ  : 1.990e+05 (roughly 45 MB of memory)
#  Factor Ops : 2.556e+07 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.90 seconds (1.10 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3186    4.6108018e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 3186 iterations and 1.11 seconds (1.25 work units)
# Optimal objective  4.610801786e+08
# Demand met: 0 out of 464242865.0524712
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C2A650740>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 448846 rows, 605373 columns and 2219425 nonzeros
# Model fingerprint: 0x10bad035
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 433886 rows and 499015 columns
# Presolve time: 1.04s
# Presolved: 14960 rows, 106358 columns, 224130 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  AA' NZ     : 1.180e+05
#  Factor NZ  : 2.204e+05 (roughly 50 MB of memory)
#  Factor Ops : 2.882e+07 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 1.19 seconds (1.27 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3486    5.3271311e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 3486 iterations and 1.46 seconds (1.46 work units)
# Optimal objective  5.327131115e+08
# Demand met: 0 out of 536493933.0558584
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BD7DF01C0>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 513230 rows, 692281 columns and 2535875 nonzeros
# Model fingerprint: 0xbe467d6d
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 493657 rows and 560987 columns
# Presolve time: 1.05s
# Presolved: 19573 rows, 131294 columns, 281376 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  AA' NZ     : 1.522e+05
#  Factor NZ  : 3.162e+05 (roughly 60 MB of memory)
#  Factor Ops : 5.973e+07 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 1.21 seconds (1.49 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4684    6.1028826e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 4684 iterations and 1.49 seconds (1.69 work units)
# Optimal objective  6.102882567e+08
# Demand met: 0 out of 614598820.7760919
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE002A180>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 581970 rows, 785101 columns and 2872875 nonzeros
# Model fingerprint: 0x55368f5b
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 556196 rows and 614325 columns
# Presolve time: 1.32s
# Presolved: 25774 rows, 170776 columns, 373264 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.11s
#
# Barrier statistics:
#  AA' NZ     : 2.077e+05
#  Factor NZ  : 5.161e+05 (roughly 80 MB of memory)
#  Factor Ops : 1.561e+08 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 1.60 seconds (1.74 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     5950    6.9046030e+08   0.000000e+00   0.000000e+00      2s
#
# Solved in 5950 iterations and 1.93 seconds (1.96 work units)
# Optimal objective  6.904603002e+08
# Demand met: 0 out of 694484732.2323743
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE0162900>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 654586 rows, 882873 columns and 3236425 nonzeros
# Model fingerprint: 0xb8177714
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 622800 rows and 645549 columns
# Presolve time: 1.77s
# Presolved: 31786 rows, 237324 columns, 571140 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.43s
#
# Barrier performed 0 iterations in 2.32 seconds (2.19 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     8084    7.8145287e+08   0.000000e+00   0.000000e+00      3s
#
# Solved in 8084 iterations and 2.74 seconds (2.30 work units)
# Optimal objective  7.814528669e+08
# Demand met: 0 out of 786036409.7902584
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE0662C80>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 731896 rows, 987233 columns and 3616300 nonzeros
# Model fingerprint: 0x7cdd9069
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 696215 rows and 717127 columns
# Presolve time: 1.91s
# Presolved: 35681 rows, 270106 columns, 675826 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.23s
#
# Barrier performed 0 iterations in 2.34 seconds (2.40 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     9094    8.6927592e+08   0.000000e+00   0.000000e+00      3s
#
# Solved in 9094 iterations and 2.82 seconds (2.59 work units)
# Optimal objective  8.692759211e+08
# Demand met: 0 out of 873813784.5529349
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C8DCD7340>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 813444 rows, 1097269 columns and 4018200 nonzeros
# Model fingerprint: 0xd6680625
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 773364 rows and 763067 columns
# Presolve time: 2.11s
# Presolved: 40080 rows, 334202 columns, 884974 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.29s
#
# Barrier performed 0 iterations in 2.59 seconds (2.77 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    11952    9.6218675e+08   0.000000e+00   0.000000e+00      3s
#
# Solved in 11952 iterations and 3.06 seconds (2.96 work units)
# Optimal objective  9.621867504e+08
# Demand met: 0 out of 967186302.1749529
# Percent of demand met: 0.0

# %%
plt.plot(list(range(5, 201, 10)),times)
plt.suptitle('Solving Time vs. Graph Size', fontweight='bold')
plt.title('Max Throughput',fontsize='small')
plt.xticks(range(5, 201, 10))
plt.tick_params('x', labelsize=6)
plt.xlabel('# Nodes')
plt.ylabel('Time (s)')
plt.savefig('extra-credit.png')
plt.show()
