# %%
from main import *

# %%
graph = parse_topology('topology.txt')
draw(graph)

# %%
import matplotlib.pyplot as plt

times = []
for size in range(10, 401, 20):
    graph = generate_graph(size)
    demands = generate_demands(size)
    model, flow = create_mcf_model(graph, demands)
    times.append(model.Runtime)

plt.plot(list(range(10, 401, 20)),times)
plt.suptitle('Time vs. Graph Size', fontweight='bold')
plt.title('Max Throughput',fontsize='small')
plt.xlabel('# Nodes')
plt.ylabel('Time (s)')
plt.savefig('extra-credit.png')
plt.show()
# Out:
# <enumerate object at 0x0000027BE2ADE440>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 4538 rows, 5213 columns and 17781 nonzeros
# Model fingerprint: 0x4cf230da
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 4538 rows and 5213 columns
# Presolve time: 0.02s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.0738918e+06   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.03 seconds (0.01 work units)
# Optimal objective  2.073891811e+06
# Demand met: 0 out of 2274245.1004881235
# Percent of demand met: 0.0
# <enumerate object at 0x0000027D42E0D180>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 26766 rows, 33307 columns and 120124 nonzeros
# Model fingerprint: 0x0082e960
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 26348 rows and 32119 columns
# Presolve time: 0.06s
# Presolved: 418 rows, 1188 columns, 1769 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.290e+02
#  Factor NZ  : 1.265e+03 (roughly 1 MB of memory)
#  Factor Ops : 1.217e+04 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.07 seconds (0.05 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       10    2.2217236e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.09 seconds (0.06 work units)
# Optimal objective  2.221723637e+07
# Demand met: 0 out of 22973735.97160868
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE071E940>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 54802 rows, 73175 columns and 267782 nonzeros
# Model fingerprint: 0x5b852dd8
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 54802 rows and 73175 columns
# Presolve time: 0.11s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.2384847e+07   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.14 seconds (0.14 work units)
# Optimal objective  6.238484742e+07
# Demand met: 0 out of 63726192.543460354
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BE071A2C0>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 103994 rows, 140183 columns and 514284 nonzeros
# Model fingerprint: 0x5c837308
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 103994 rows and 140183 columns
# Presolve time: 0.21s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2380590e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.27 seconds (0.28 work units)
# Optimal objective  1.238059020e+08
# Demand met: 0 out of 125564813.50730522
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C29897A40>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 172308 rows, 232465 columns and 850090 nonzeros
# Model fingerprint: 0x680a2cf4
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 169441 rows and 221778 columns
# Presolve time: 0.35s
# Presolved: 2867 rows, 10687 columns, 18164 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 7.251e+03
#  Factor NZ  : 1.160e+04 (roughly 6 MB of memory)
#  Factor Ops : 1.064e+05 (less than 1 second per iteration)
#  Threads    : 1
#
# Barrier performed 0 iterations in 0.38 seconds (0.41 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#       92    2.0337974e+08   0.000000e+00   0.000000e+00      0s
#
# Solved in 92 iterations and 0.48 seconds (0.50 work units)
# Optimal objective  2.033797382e+08
# Demand met: 0 out of 205823244.13270622
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C29649640>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 257780 rows, 347701 columns and 1274000 nonzeros
# Model fingerprint: 0x8fb096cc
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 250266 rows and 293899 columns
# Presolve time: 0.58s
# Presolved: 7514 rows, 53802 columns, 112082 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.03s
#
# Barrier statistics:
#  AA' NZ     : 5.767e+04
#  Factor NZ  : 9.286e+04 (roughly 26 MB of memory)
#  Factor Ops : 5.721e+06 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 0.67 seconds (0.69 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1228    3.0437889e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 1228 iterations and 0.83 seconds (0.80 work units)
# Optimal objective  3.043788889e+08
# Demand met: 0 out of 307121082.56770176
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BF40B8900>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 360472 rows, 486165 columns and 1782850 nonzeros
# Model fingerprint: 0xa7942b87
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 349092 rows and 405083 columns
# Presolve time: 0.86s
# Presolved: 11380 rows, 81082 columns, 170616 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.05s
#
# Barrier statistics:
#  AA' NZ     : 8.930e+04
#  Factor NZ  : 1.542e+05 (roughly 40 MB of memory)
#  Factor Ops : 1.409e+07 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 1.00 seconds (1.00 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     2454    4.2704737e+08   0.000000e+00   0.000000e+00      1s
#
# Solved in 2454 iterations and 1.22 seconds (1.15 work units)
# Optimal objective  4.270473681e+08
# Demand met: 0 out of 430500799.7877107
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BDDF6A540>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 480482 rows, 648065 columns and 2375225 nonzeros
# Model fingerprint: 0x8010c135
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 461763 rows and 523485 columns
# Presolve time: 1.19s
# Presolved: 18719 rows, 124580 columns, 267740 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  AA' NZ     : 1.453e+05
#  Factor NZ  : 2.957e+05 (roughly 60 MB of memory)
#  Factor Ops : 5.153e+07 (less than 1 second per iteration)
#  Threads    : 4
#
# Barrier performed 0 iterations in 1.40 seconds (1.39 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     4442    5.7034342e+08   0.000000e+00   0.000000e+00      2s
#
# Solved in 4442 iterations and 1.71 seconds (1.58 work units)
# Optimal objective  5.703434194e+08
# Demand met: 0 out of 574060009.9674864
# Percent of demand met: 0.0
# <enumerate object at 0x0000027D4A514200>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 617704 rows, 833189 columns and 3052450 nonzeros
# Model fingerprint: 0x44a362d6
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 588256 rows and 630345 columns
# Presolve time: 1.71s
# Presolved: 29448 rows, 202844 columns, 463830 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.33s
#
# Barrier performed 0 iterations in 2.17 seconds (1.96 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     7038    7.3219577e+08   0.000000e+00   0.000000e+00      3s
#
# Solved in 7038 iterations and 2.62 seconds (2.13 work units)
# Optimal objective  7.321957677e+08
# Demand met: 0 out of 736166025.7398024
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BA616EC40>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 772108 rows, 1041477 columns and 3814900 nonzeros
# Model fingerprint: 0xf23d5131
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 734222 rows and 734821 columns
# Presolve time: 2.16s
# Presolved: 37886 rows, 306656 columns, 789076 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.33s
#
# Barrier performed 0 iterations in 2.73 seconds (2.58 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    10718    9.1538498e+08   0.000000e+00   0.000000e+00      3s
#
# Solved in 10718 iterations and 3.22 seconds (2.78 work units)
# Optimal objective  9.153849768e+08
# Demand met: 0 out of 920279763.2604101
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BFC41F540>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 943644 rows, 1272829 columns and 4663200 nonzeros
# Model fingerprint: 0xa8ccf852
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 897017 rows and 867949 columns
# Presolve time: 2.59s
# Presolved: 46627 rows, 404880 columns, 1106748 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.46s
#
# Barrier performed 0 iterations in 3.34 seconds (3.17 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    15596    1.1181227e+09   0.000000e+00   0.000000e+00      4s
#
# Solved in 15596 iterations and 3.98 seconds (3.42 work units)
# Optimal objective  1.118122704e+09
# Demand met: 0 out of 1123418859.7909863
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BDC116F40>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1132392 rows, 1527405 columns and 5596350 nonzeros
# Model fingerprint: 0x16291bb6
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 1076399 rows and 1031741 columns
# Presolve time: 3.50s
# Presolved: 55993 rows, 495664 columns, 1392824 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.67s
#
# Barrier performed 0 iterations in 4.63 seconds (3.81 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    20500    1.3458568e+09   0.000000e+00   0.000000e+00      5s
#
# Solved in 20500 iterations and 5.46 seconds (4.17 work units)
# Optimal objective  1.345856843e+09
# Demand met: 0 out of 1351669227.2608345
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BB1B20140>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1338066 rows, 1804633 columns and 6617925 nonzeros
# Model fingerprint: 0x249dff06
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 1271960 rows and 1218215 columns
# Presolve time: 3.94s
# Presolved: 66106 rows, 586418 columns, 1663962 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.77s
#
# Barrier performed 0 iterations in 5.13 seconds (4.64 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    24366    1.5890904e+09   0.000000e+00   0.000000e+00      6s
#
# Solved in 24366 iterations and 6.01 seconds (5.05 work units)
# Optimal objective  1.589090433e+09
# Demand met: 0 out of 1595346174.2128017
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C23512880>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1561328 rows, 2105837 columns and 7719650 nonzeros
# Model fingerprint: 0x0eb68b30
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 1484401 rows and 1407893 columns
# Presolve time: 4.64s
# Presolved: 76927 rows, 697944 columns, 1986512 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.95s
#
# Barrier performed 0 iterations in 6.08 seconds (5.50 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    31284    1.8559374e+09   0.000000e+00   0.000000e+00      7s
#
# Solved in 31284 iterations and 7.08 seconds (5.80 work units)
# Optimal objective  1.855937441e+09
# Demand met: 0 out of 1862754881.6320648
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C2A61B2C0>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1802088 rows, 2430837 columns and 8902650 nonzeros
# Model fingerprint: 0x7230d3b1
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 1713518 rows and 1623143 columns (presolve time = 5s) ...
# Presolve removed 1713518 rows and 1623143 columns
# Presolve time: 5.56s
# Presolved: 88570 rows, 807694 columns, 2308120 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.98s
#
# Barrier performed 0 iterations in 7.24 seconds (6.08 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    36408    2.1358354e+09   0.000000e+00   0.000000e+00      8s
#
# Solved in 36408 iterations and 8.41 seconds (6.90 work units)
# Optimal objective  2.135835417e+09
# Demand met: 0 out of 2143300802.4326682
# Percent of demand met: 0.0
# <enumerate object at 0x0000027C40822400>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2059508 rows, 2777957 columns and 10177400 nonzeros
# Model fingerprint: 0x38791cb4
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 1958488 rows and 1820057 columns (presolve time = 5s) ...
# Presolve removed 1958489 rows and 1851029 columns
# Presolve time: 7.03s
# Presolved: 101019 rows, 926928 columns, 2640930 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 1.39s
#
# Barrier performed 0 iterations in 9.14 seconds (7.38 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    42836    2.4402699e+09   0.000000e+00   0.000000e+00     11s
#
# Solved in 42836 iterations and 10.65 seconds (7.97 work units)
# Optimal objective  2.440269859e+09
# Demand met: 0 out of 2448185004.4902053
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BDD3E2800>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2334320 rows, 3148661 columns and 11534750 nonzeros
# Model fingerprint: 0x0796c03e
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 2220065 rows and 2062961 columns (presolve time = 5s) ...
# Presolve removed 2220069 rows and 2093019 columns
# Presolve time: 7.19s
# Presolved: 114251 rows, 1055642 columns, 3031470 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 1.39s
#
# Barrier performed 0 iterations in 9.43 seconds (8.72 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    49266    2.7687053e+09   0.000000e+00   0.000000e+00     11s
#
# Solved in 49266 iterations and 10.85 seconds (9.14 work units)
# Optimal objective  2.768705298e+09
# Demand met: 0 out of 2777093180.1850963
# Percent of demand met: 0.0
# <enumerate object at 0x0000027BDD691940>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2626652 rows, 3543205 columns and 12973100 nonzeros
# Model fingerprint: 0x65e5e755
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 2474178 rows and 2321705 columns (presolve time = 5s) ...
# Presolve removed 2498279 rows and 2350801 columns
# Presolve time: 9.05s
# Presolved: 128373 rows, 1192404 columns, 3429184 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 1.83s
#
# Barrier performed 0 iterations in 11.93 seconds (9.84 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    57266    3.1101004e+09   0.000000e+00   0.000000e+00     14s
#
# Solved in 57266 iterations and 13.73 seconds (10.51 work units)
# Optimal objective  3.110100414e+09
# Demand met: 0 out of 3118847671.098289
# Percent of demand met: 0.0
# <enumerate object at 0x0000027B953FAB40>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 2934938 rows, 3958457 columns and 14512025 nonzeros
# Model fingerprint: 0xffc2f4ee
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 2764047 rows and 2593157 columns (presolve time = 5s) ...
# Presolve removed 2791844 rows and 2625335 columns
# Presolve time: 9.86s
# Presolved: 143094 rows, 1333122 columns, 3831712 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 1.72s
#
# Barrier performed 0 iterations in 12.60 seconds (10.99 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    63032    3.4899928e+09   0.000000e+00   0.000000e+00     14s
#
# Solved in 63032 iterations and 14.40 seconds (11.82 work units)
# Optimal objective  3.489992758e+09
# Demand met: 0 out of 3499122211.4712653
# Percent of demand met: 0.0
# <enumerate object at 0x0000027B9364A340>
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-9750H CPU @ 2.60GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3261948 rows, 4399957 columns and 16116900 nonzeros
# Model fingerprint: 0xd46bebf0
# Coefficient statistics:
#   Matrix range     [2e-07, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+03, 5e+06]
# Presolve removed 3072402 rows and 2882857 columns (presolve time = 6s) ...
# Presolve removed 3103174 rows and 2918449 columns (presolve time = 10s) ...
# Presolve removed 3103175 rows and 2918449 columns
# Presolve time: 11.35s
# Presolved: 158773 rows, 1481508 columns, 4266142 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 1.98s
#
# Barrier performed 0 iterations in 14.55 seconds (12.30 work units)
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with primal simplex
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    70344    3.8749355e+09   0.000000e+00   0.000000e+00     17s
#
# Solved in 70344 iterations and 16.67 seconds (13.26 work units)
# Optimal objective  3.874935504e+09
# Demand met: 0 out of 3884818460.876107
# Percent of demand met: 0.0
